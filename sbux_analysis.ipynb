# %%
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\HUAWEI\Downloads
# ...

# %%
import pandas as pd

daily = pd.read_csv(r"C:\sbux_project\data\sbux_daily.csv")
monthly = pd.read_csv(r"C:\sbux_project\data\sbux_monthly.csv")
security = pd.read_csv(r"C:\sbux_project\data\sbux_security.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 3
#       1 import pandas as pd
# ----> 3 daily = pd.read_csv(r"C:\sbux_project\data\sbux_daily.csv")
#       4 monthly = pd.read_csv(r"C:\sbux_project\data\sbux_monthly.csv")
#       5 security = pd.read_csv(r"C:\sbux_project\data\sbux_security.csv")
#
# ...

# %%
if "data" in os.listdir():
    print("data 文件夹内容：", os.listdir("data"))
else:
    print("当前目录下没有 data 文件夹")
# Out:
# 当前目录下没有 data 文件夹

# %%
import pandas as pd

daily = pd.read_csv(r"C:\stock_project\data\sbux_daily.csv")
monthly = pd.read_csv(r"C:\stock_project\data\sbux_monthly.csv")
security = pd.read_csv(r"C:\stock_project\data\sbux_security.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 import pandas as pd
# ----> 3 daily = pd.read_csv(r"C:\stock_project\data\sbux_daily.csv")
#       4 monthly = pd.read_csv(r"C:\stock_project\data\sbux_monthly.csv")
#       5 security = pd.read_csv(r"C:\stock_project\data\sbux_security.csv")
#
# ...

# %%
excel_files = [f for f in os.listdir() if f.endswith('.xlsx')]
print(excel_files)
# Out:
# ['Balkan states_Micro-financing institution.xlsx', 'Balkan states_saving bank (1).xlsx', 'Balkan states_saving bank.xlsx', 'Baltic states_Cooperative bank (1).xlsx', 'Baltic states_Cooperative bank.xlsx', 'change_the_file_name.xlsx', 'china_monthly_stock_data.xlsx', 'csmar_sample_datetime.xlsx', 'csmar_sample_string_date.xlsx', 'Export 02_02_2026 14_32 (1).xlsx', 'Export 02_02_2026 14_32.xlsx', 'Export 23_02_2026 08_01 (1).xlsx', 'Export 23_02_2026 08_01.xlsx', 'Nordic states_Saving bank (1).xlsx', 'Nordic states_Saving bank.xlsx', 'Scandinavia_Private banking.xlsx', 'South and Central America_Fintech bank.xlsx', 'South and Central America_Micro-financing institution.xlsx', 'South and Central America_Private banking.xlsx', 'us_financial_data.xlsx', 'Western Europe_Cooperative bank (1).xlsx', 'Western Europe_Cooperative bank.xlsx']

# %%
import os
print([f for f in os.listdir() if f.endswith('.csv')])
# Out:
# []

# %%
print([f for f in os.listdir() if f.endswith('.xlsx')])
# Out:
# ['Balkan states_Micro-financing institution.xlsx', 'Balkan states_saving bank (1).xlsx', 'Balkan states_saving bank.xlsx', 'Baltic states_Cooperative bank (1).xlsx', 'Baltic states_Cooperative bank.xlsx', 'change_the_file_name.xlsx', 'china_monthly_stock_data.xlsx', 'csmar_sample_datetime.xlsx', 'csmar_sample_string_date.xlsx', 'Export 02_02_2026 14_32 (1).xlsx', 'Export 02_02_2026 14_32.xlsx', 'Export 23_02_2026 08_01 (1).xlsx', 'Export 23_02_2026 08_01.xlsx', 'Nordic states_Saving bank (1).xlsx', 'Nordic states_Saving bank.xlsx', 'Scandinavia_Private banking.xlsx', 'South and Central America_Fintech bank.xlsx', 'South and Central America_Micro-financing institution.xlsx', 'South and Central America_Private banking.xlsx', 'us_financial_data.xlsx', 'Western Europe_Cooperative bank (1).xlsx', 'Western Europe_Cooperative bank.xlsx']
